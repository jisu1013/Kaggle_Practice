# %%
## This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
train_17 = pd.read_csv('/kaggle/input/know-recommendation/train/KNOW_2017.csv')
train_18 = pd.read_csv('/kaggle/input/know-recommendation/train/KNOW_2018.csv')
train_19 = pd.read_csv('/kaggle/input/know-recommendation/train/KNOW_2019.csv')
train_20 = pd.read_csv('/kaggle/input/know-recommendation/train/KNOW_2020.csv')

# %%
test_17 = pd.read_csv('/kaggle/input/know-recommendation/test/KNOW_2017_test.csv')
test_18 = pd.read_csv('/kaggle/input/know-recommendation/test/KNOW_2018_test.csv')
test_19 = pd.read_csv('/kaggle/input/know-recommendation/test/KNOW_2019_test.csv')
test_20 = pd.read_csv('/kaggle/input/know-recommendation/test/KNOW_2020_test.csv')

# %%
train_17

# %%
train_17['bq19_1']

# %%
pd.options.display.max_columns = 999
train_18

# %%
train_19

# %%
train_20

# %%
train_17 = train_17.rename(columns={'bq19_1':'text'})
train_18 = train_18.rename(columns={'bq28_1':'text'})
train_19 = train_19.rename(columns={'bq20_1':'text'})
train_20 = train_20.rename(columns={'bq20_1':'text'})

# %%
test_17 = test_17.rename(columns={'bq19_1':'text'})
test_18 = test_18.rename(columns={'bq28_1':'text'})
test_19 = test_19.rename(columns={'bq20_1':'text'})
test_20 = test_20.rename(columns={'bq20_1':'text'})

# %%
for column in ['bq17', 'bq18_1', 'bq18_2', 'bq18_3', 'bq18_4', 'bq18_5', 'bq18_6', 'bq18_7']:
    train_17.rename(columns={column:(column+'_17')}, inplace=True)

# %%
for column in ['bq13', 'bq14', 'bq15', 'bq16', 'bq17', 'bq19', 'bq20', 'bq21', 'bq25', 'bq25_1', 'bq26_1', 'bq26_1a', 'bq26_2', 'bq26_2a', 'bq26_3', 'bq26_3a', 'bq26_4', 'bq26_4a', 'bq27', 'bq28', 'bq28_1']:
    train_18.rename(columns={column:(column+'_18')}, inplace=True)

# %%
for column in range(29, 38):
    train_18.rename(columns={str(column):(str(column+1))}, inplace=True)

# %%
train_18.rename(columns={'bq37_1':'bq38_1', 'bq38':'bq39_1', 'bq38_1':'bq39_2_1', 'bq38_2':'bq39_2_2', 'bq39':'bq40', 'bq40':'bq40_1'}, inplace=True)

# %%
train_18['bq40_1'].replace(" ",-1, inplace=True)
train_18['bq40_1'].replace("지식재산학",-1,inplace=True)
train_18['bq40_1'].replace("nan",-1,inplace=True)

# %%
train_18['bq40_1'] = pd.to_numeric(train_18['bq40_1'])

# %%
train_18['bq40_1'].unique()

# %%
train_19.rename(columns={'bq13_1':'bq15_1', 'bq13_2':'bq15_2', 'bq13_3':'bq15_3'}, inplace=True)

# %%
for column in ['bq14_1', 'bq14_2', 'bq14_3', 'bq14_4', 'bq14_5', 'bq15', 'bq16_1', 'bq16_2', 'bq16_3', 'bq16_4', 'bq16_5', 'bq17', 'bq19', 'bq21_1', 'bq21_2', 'bq21_3']:
    train_19.rename(columns={column:(column+'_19')}, inplace=True)

# %%
train_19.rename(columns={'bq20':'bq19', 'bq20_1':'bq19_1', 'bq29':'bq40', 'bq30':'bq40_1', 'bq31_1':'bq41_1', 'bq31_2':'bq41_2', 'bq31_3':'bq41_3'}, inplace=True)

# %%
train_19.rename(columns={'bq22':'bq32', 'bq23':'bq33', 'bq24':'bq34', 'bq25':'bq36', 'bq26':'bq37', 'bq27':'bq38', 'bq27_1':'bq38_1', 'bq28':'bq39_1', 'bq28_1':'bq39_2_1', 'bq28_2':'bq39_2_2'}, inplace=True)

# %%
train_20.rename(columns={'bq13_1':'bq15_1', 'bq13_2':'bq15_2', 'bq13_3':'bq15_3'}, inplace=True)

# %%
for column in ['bq14_1', 'bq14_2', 'bq14_3', 'bq14_4', 'bq14_5', 'bq14_6', 'bq14_7', 'bq15', 'bq16_1', 'bq16_2', 'bq16_3', 'bq16_4', 'bq16_5', 'bq16_6', 'bq16_7', 'bq16_8', 'bq16_9', 'bq16_10', 'bq17']:
    train_20.rename(columns={column:(column+'_20')}, inplace=True)

# %%
train_20.rename(columns={'bq19':'bq19_18', 'bq20':'bq19', 'bq20_1':'bq19_1'}, inplace=True)

# %%
train_20.rename(columns={'bq24':'bq36', 'bq25':'bq37', 'bq26':'bq38', 'bq26_1':'bq38_1', 'bq27_1':'bq39_1', 'bq27_2':'bq39_2', 'bq28':'bq40', 'bq29':'bq40_1', 'bq30_1':'bq41_1', 'bq30_2':'bq41_2', 'bq30_3':'bq41_3'}, inplace=True)

# %%
#test_17 = pd.read_csv('/kaggle/input/know-recommendation/test/KNOW_2017_test.csv')
#test_18 = pd.read_csv('/kaggle/input/know-recommendation/test/KNOW_2018_test.csv')
#test_19 = pd.read_csv('/kaggle/input/know-recommendation/test/KNOW_2019_test.csv')
#test_20 = pd.read_csv('/kaggle/input/know-recommendation/test/KNOW_2020_test.csv')

# %%
for column in ['bq17', 'bq18_1', 'bq18_2', 'bq18_3', 'bq18_4', 'bq18_5', 'bq18_6', 'bq18_7']:
    test_17.rename(columns={column:(column+'_17')}, inplace=True)
    
for column in ['bq13', 'bq14', 'bq15', 'bq16', 'bq17', 'bq19', 'bq20', 'bq21', 'bq25', 'bq25_1', 'bq26_1', 'bq26_1a', 'bq26_2', 'bq26_2a', 'bq26_3', 'bq26_3a', 'bq26_4', 'bq26_4a', 'bq27', 'bq28', 'bq28_1']:
    test_18.rename(columns={column:(column+'_18')}, inplace=True)
    
for column in range(29, 38):
    test_18.rename(columns={str(column):(str(column+1))}, inplace=True)
    
test_18.rename(columns={'bq37_1':'bq38_1', 'bq38':'bq39_1', 'bq38_1':'bq39_2_1', 'bq38_2':'bq39_2_2', 'bq39':'bq40', 'bq40':'bq40_1'}, inplace=True)
test_19.rename(columns={'bq13_1':'bq15_1', 'bq13_2':'bq15_2', 'bq13_3':'bq15_3'}, inplace=True)

for column in ['bq14_1', 'bq14_2', 'bq14_3', 'bq14_4', 'bq14_5', 'bq15', 'bq16_1', 'bq16_2', 'bq16_3', 'bq16_4', 'bq16_5', 'bq17', 'bq19', 'bq21_1', 'bq21_2', 'bq21_3']:
    test_19.rename(columns={column:(column+'_19')}, inplace=True)
    
test_19.rename(columns={'bq20':'bq19', 'bq20_1':'bq19_1', 'bq29':'bq40', 'bq30':'bq40_1', 'bq31_1':'bq41_1', 'bq31_2':'bq41_2', 'bq31_3':'bq41_3'}, inplace=True)
test_19.rename(columns={'bq22':'bq32', 'bq23':'bq33', 'bq24':'bq34', 'bq25':'bq36', 'bq26':'bq37', 'bq27':'bq38', 'bq27_1':'bq38_1', 'bq28':'bq39_1', 'bq28_1':'bq39_2_1', 'bq28_2':'bq39_2_2'}, inplace=True)
test_20.rename(columns={'bq13_1':'bq15_1', 'bq13_2':'bq15_2', 'bq13_3':'bq15_3'}, inplace=True)

for column in ['bq14_1', 'bq14_2', 'bq14_3', 'bq14_4', 'bq14_5', 'bq14_6', 'bq14_7', 'bq15', 'bq16_1', 'bq16_2', 'bq16_3', 'bq16_4', 'bq16_5', 'bq16_6', 'bq16_7', 'bq16_8', 'bq16_9', 'bq16_10', 'bq17']:
    test_20.rename(columns={column:(column+'_20')}, inplace=True)
    
test_20.rename(columns={'bq19':'bq19_18', 'bq20':'bq19', 'bq20_1':'bq19_1'}, inplace=True)
test_20.rename(columns={'bq24':'bq36', 'bq25':'bq37', 'bq26':'bq38', 'bq26_1':'bq38_1', 'bq27_1':'bq39_1', 'bq27_2':'bq39_2', 'bq28':'bq40', 'bq29':'bq40_1', 'bq30_1':'bq41_1', 'bq30_2':'bq41_2', 'bq30_3':'bq41_3'}, inplace=True)

# %%
#pd.options.display.max_columns = 1000
#pd.options.display.max_rows = 1000

# %%
train_17

# %%
train_17.columns[train_17.columns.dtype == 'object']

# %%
train_18.columns

# %%
train_19.columns

# %%
train_20.columns[102:]

# %%
train = pd.concat([train_17, train_18, train_19, train_20])

# %%
train

# %%
train['knowcode'].value_counts()

# %%
test = pd.concat([test_17,test_18,test_19,test_20])
test

# %%
all_data = pd.concat([train,test])
all_data

# %% [markdown]
# count vectorizer, tf-idf -> 빈도수 기반

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(min_df=5)
text_tfidf = tfidf.fit_transform(list(all_data['text'].fillna('')))

# %%
text_tfidf

# %% [markdown]
# - n_components 조절해보기
# - 먼저 scaling (sub_linear)

# %%
from sklearn.decomposition import TruncatedSVD

svd = TruncatedSVD(n_components=10)
text_svd = svd.fit_transform(text_tfidf)
text_svd

# %%
for i in range(10):
    all_data['직업선택이유_'+str(i)] = text_svd[:,i]
all_data

# %%
svd_df = pd.DataFrame(text_svd)
svd_df.columns = ['svd_'+str(i) for i in range(10)]
svd_df

# %%
all_data = all_data.reset_index(drop=True)
all_data

# %%
all_data = pd.concat([all_data, svd_df], axis=1)

# %%
all_data

# %%
all_data_2 = all_data.drop(columns=['idx','knowcode','text'])

# %%
#all_data_2.nunique().sort_values()

# %%
all_data_2['bq5_2'].value_counts() #문자열column

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
cat = all_data_2.columns[all_data_2.dtypes == 'object']
cat

# %%
for i in cat:
    all_data_2[i] = le.fit_transform(list(all_data_2[i]))
all_data_2

# %%
train_2 = all_data_2[:len(train)]
test_2 = all_data_2[len(train):]

# %%
#from catboost import CatBoostClassifier

#cbc = CatBoostClassifier(task_type='GPU')
#cbc.fit(train_2, train['knowcode'])

# %%
from sklearn.model_selection import train_test_split

x_train, x_valid, y_train, y_valid = train_test_split(train_2, train['knowcode'], test_size=0.2, random_state=42, stratify=train['knowcode'])

# %%
#y_train.value_counts()

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(tree_method='gpu_hist', learning_rate=0.2)#, n_estimators=1000)
xgb.fit(train_2, train['knowcode'])#, eval_set=[(x_valid, y_valid)], early_stopping_rounds=15)

# %%
#from xgboost import plot_importance
#import matplotlib.pyplot as plt
#%matplotlib inline

#fig, ax = plt.subplots(figsize=(10, 12))
xgb.feature_importances_

# %%
result = xgb.predict(test_2)
result

# %%
x_result = xgb.predict(x_valid)
x_result

# %%
from sklearn.metrics import f1_score

f1_score(y_valid, x_result, average='macro')

# %%
sub = pd.read_csv('../input/know-recommendation/sample_submission.csv')
sub

# %%
sub['knowcode'] = result
sub

# %%
sub.to_csv('sub.csv',index=False)

# %%
#train['knowcode']
